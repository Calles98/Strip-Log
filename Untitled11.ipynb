# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.graph_objects as go
import plotly.express as px  # For accessing Plotly color scales

# %%
alt_file_path = "/content/Evelyn_Alteration_Type_20241114.csv"
alt_data = pd.read_csv(alt_file_path)
alt_data.head(15)
# Out:
#        Collar  GeolFrom  GeolTo  Chk AlterationComment AlterationType1  \
# 0   EVE-20-01      0.00    9.10    0               NaN       Chloritic
# 1   EVE-20-01      9.10   17.70    0               NaN       Chloritic
# 2   EVE-20-01     17.70   20.70    0               NaN       Chloritic
# 3   EVE-20-01     20.70   23.00    0               NaN       Chloritic
# 4   EVE-20-01     23.00   26.40    0               NaN       Chloritic
# 5   EVE-20-01     26.40   28.30    0               NaN       Chloritic
# 6   EVE-20-01     28.30   29.05    0               NaN       Sericitic
# 7   EVE-20-01     29.05   32.80    0               NaN       Chloritic
# 8   EVE-20-01     32.80   33.35    0               NaN       Sericitic
# 9   EVE-20-01     33.35   39.90    0               NaN       Sericitic
# 10  EVE-20-01     39.90   42.50    0               NaN       Sericitic
# 11  EVE-20-01     42.50   48.05    0               NaN      Propylitic
# 12  EVE-20-01     48.05   50.70    0               NaN       Chloritic
# 13  EVE-20-01     50.70   65.55    0               NaN       Sericitic
# 14  EVE-20-01     65.55   71.25    0               NaN       Sericitic
#
#    AlterationTypeIntensity1 AlterationTypeStyle1 AlterationType2  \
# 0                    Strong              No data      Propylitic
# 1                  Moderate              No data      Propylitic
# 2                    Strong              No data      Propylitic
# 3                  Moderate              No data      Propylitic
# 4                  Moderate              No data      Propylitic
# 5                    Strong              No data      Propylitic
# 6                  Moderate              No data       Chloritic
# 7                  Moderate              No data      Propylitic
# 8                  Moderate              No data       Chloritic
# 9                    Strong              No data       Chloritic
# 10                 Moderate              No data        Argillic
# 11                 Moderate              No data       Chloritic
# 12                     Weak              No data        Argillic
# 13                 Moderate              No data      Propylitic
# 14                 Moderate              No data      Propylitic
#
#    AlterationTypeIntensity2  ... AlterationType3 AlterationTypeIntensity3  \
# 0                  Moderate  ...  Silicification                 Moderate
# 1                      Weak  ...       Sericitic                 Moderate
# 2                  Moderate  ...       Sericitic                     Weak
# 3                  Moderate  ...       Sericitic                 Moderate
# 4                      Weak  ...       Sericitic                     Weak
# 5                    Strong  ...       Sericitic                   Strong
# 6                      Weak  ...         No data                  No data
# 7                  Moderate  ...       Sericitic                 Moderate
# 8                      Weak  ...      Propylitic                     Weak
# 9                  Moderate  ...      Propylitic                 Moderate
# 10                 Moderate  ...  Silicification                     Weak
# 11                     Weak  ...        Argillic                     Weak
# 12                     Weak  ...       Sericitic                     Weak
# 13                     Weak  ...       Chloritic                     Weak
# 14                     Weak  ...       Chloritic                     Weak
#
#    AlterationTypeStyle3 AlterationType4 AlterationTypeIntensity4  \
# 0               No data       Sericitic                     Weak
# 1               No data  Silicification                 Moderate
# 2               No data         No data                  No data
# 3               No data  Silicification                     Weak
# 4               No data  Silicification                     Weak
# 5               No data  Silicification                     Weak
# 6               No data         No data                  No data
# 7               No data  Silicification                     Weak
# 8               No data  Silicification                     Weak
# 9               No data  Silicification                     Weak
# 10              No data         No data                  No data
# 11              No data       Sericitic                     Weak
# 12              No data  Silicification                     Weak
# 13              No data        Argillic                     Weak
# 14              No data        Argillic                     Weak
#
#    AlterationTypeStyle4 AlterationType5 AlterationTypeIntensity5  \
# 0               No data         No data                  No data
# 1               No data         No data                  No data
# 2               No data         No data                  No data
# 3               No data         No data                  No data
# 4               No data         No data                  No data
# 5               No data         No data                  No data
# 6               No data         No data                  No data
# 7               No data         No data                  No data
# 8               No data         No data                  No data
# 9               No data         No data                  No data
# 10              No data         No data                  No data
# 11              No data  Silicification                     Weak
# 12              No data         No data                  No data
# 13              No data  Silicification                     Weak
# 14              No data  Silicification                     Weak
#
#    AlterationTypeStyle5 MetallurgicalType
# 0               No data           No data
# 1               No data           No data
# 2               No data           No data
# 3               No data           No data
# 4               No data           No data
# 5               No data           No data
# 6               No data           No data
# 7               No data           No data
# 8               No data           No data
# 9               No data           No data
# 10              No data           No data
# 11              No data           No data
# 12              No data           No data
# 13              No data           No data
# 14              No data           No data
#
# [15 rows x 21 columns]

# %%
alt_data['AlterationType1'].unique()
# Out:
# array(['Chloritic', 'Sericitic', 'Propylitic', 'Argillic',
#        'Silicification', 'Bleached'], dtype=object)

# %%
def plot_alteration_types(alt_types):

  for alt_type in alt_types:


    # Sample Data
    geol_from = alt_data["GeolFrom"]
    geol_to = alt_data["GeolTo"]
    alt_spec = alt_data[alt_type]

    # Calculate the widths of each bar segment (GeolTo - GeolFrom)
    bar_lengths = [end - start for start, end in zip(geol_from, geol_to)]

    # Choose a color scale
    color_scale = px.colors.qualitative.Set1  # A qualitative color scale with 9 distinct colors

    # Map each lithology type to a color from the chosen color scale
    color_mapping = {alt: color_scale[i % len(color_scale)] for i, alt in enumerate(set(alt_spec))}

    # Create a figure for the plot
    fig = go.Figure()

    # Track lithology types that have already appeared in the legend
    legend_seen = {}

    # Add each lithology type as a separate segment in the same bar
    start_point = 0
    for alt, length in zip(alt_spec, bar_lengths):
        show_legend = alt not in legend_seen  # Show legend only for the first occurrence of each lithology
        legend_seen[alt] = True  # Mark this lithology as seen

        fig.add_trace(go.Bar(
            y=[0],  # All bars are at the same y=0 level to stack on the same line
            x=[length],  # Length of the bar segment
            orientation='h',  # Horizontal bars
            name=alt,  # Name for legend
            offsetgroup=0,  # Stack the bars
            base=start_point,  # Set the base of the bar where the last ended
            marker_color=color_mapping[alt],  # Assign color based on lithology type
            marker_line_width=0,  # Remove the border line
            legendgroup=alt,  # Group all traces with the same lithology into one legend entry
            showlegend=show_legend  # Show legend only for the first trace of each lithology type
        ))
        start_point += length  # Update the start_point for the next segment

    # Update layout for stacked bar and styling
    fig.update_layout(
        xaxis_title="Depth (m)",
        yaxis=dict(showticklabels=False),  # Hide y-axis ticks and labels
        barmode='stack',  # Stack bars on top of each other
        showlegend=True,
        height=300,  # Set plot height
        legend_title="Alteration Type"
    )

    # Show the plot
    fig.show()

# %%
alt_types = ['AlterationType1', 'AlterationType2', 'AlterationType3']
plot_alteration_types(alt_types)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ac928663-b47c-4de8-b5d8-208f2d1aab57" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac928663-b47c-4de8-b5d8-208f2d1aab57")) {                    Plotly.newPlot(                        "ac928663-b47c-4de8-b5d8-208f2d1aab57",                        [{"base":0,"legendgroup":"Chloritic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"Chloritic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"Chloritic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"Chloritic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"Chloritic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"Chloritic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"Chloritic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"Propylitic","marker":{"color":"rgb(255,127,0)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"Chloritic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"base":79.25,"legendgroup":"Sericitic","marker":{"color": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="edeba4f9-2e6c-4b75-ba5c-3a1d990c9f89" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edeba4f9-2e6c-4b75-ba5c-3a1d990c9f89")) {                    Plotly.newPlot(                        "edeba4f9-2e6c-4b75-ba5c-3a1d990c9f89",                        [{"base":0,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"Chloritic","marker":{"color":"rgb(255,127,0)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"Chloritic","marker":{"color":"rgb(255,127,0)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"Chloritic","marker":{"color":"rgb(255,127,0)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"Argillic","marker":{"color":"rgb(77,175,74)","line":{"width":0}},"name":"Argillic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"Chloritic","marker":{"color":"rgb(255,127,0)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"Argillic","marker":{"color":"rgb(77,175,74)","line":{"width":0}},"name":"Argillic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"Propylitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"Argillic","marker":{"color":"rgb(77,175,74)","line":{"width":0}},"name":"Argillic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"base":79.25,"legendgroup":"Argillic","marker":{"colo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6609a366-fc24-425b-bd9a-49675139e722" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6609a366-fc24-425b-bd9a-49675139e722")) {                    Plotly.newPlot(                        "6609a366-fc24-425b-bd9a-49675139e722",                        [{"base":0,"legendgroup":"Silicification","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Silicification","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"No data","marker":{"color":"rgb(247,129,191)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":true,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"Propylitic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"Propylitic","marker":{"color":"rgb(255,255,51)","line":{"width":0}},"name":"Propylitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"Silicification","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Silicification","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"Argillic","marker":{"color":"rgb(77,175,74)","line":{"width":0}},"name":"Argillic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"Sericitic","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Sericitic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"Chloritic","marker":{"color":"rgb(166,86,40)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"Chloritic","marker":{"color":"rgb(166,86,40)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"Chloritic","marker":{"color":"rgb(166,86,40)","line":{"width":0}},"name":"Chloritic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"base":79.25,"legendgroup":"Chloritic","marker ...

# %% [markdown]
# Lithology

# %%
lit_file_path = "/content/Evelyn_Lithology_20241114.csv"
lit_data = pd.read_csv(lit_file_path)
lit_data.head()
# Out:
#       Collar  GeolFrom  GeolTo  Chk  \
# 0  EVE-20-01       0.0     9.1    0
# 1  EVE-20-01       9.1    17.7    0
# 2  EVE-20-01      17.7    20.7    0
# 3  EVE-20-01      20.7    23.0    0
# 4  EVE-20-01      23.0    26.4    0
#
#                                      Geology_Comment LithLocal LithContact  \
# 0  Brecciated andesite, greenish color with Qtz (...   No data     No data
# 1  Brecciated andesite, pale green, fault zone; c...   No data     No data
# 2  Andesite breccia, greenish rock, no competent ...   No data     No data
# 3  Andesite breccia; Continuation of fracture/fau...   No data     No data
# 4  Metavolcanics (gray to green) coarse to flow t...   No data     No data
#
#   LithAbund1     LithSpec1  LithMod1  ... LithSpec4 LithMod4 LithColorMod4  \
# 0    No data      Andesite   Breccia  ...   No data  No data       No data
# 1    No data      Andesite   Breccia  ...   No data  No data       No data
# 2    No data      Andesite   Breccia  ...   No data  No data       No data
# 3    No data      Andesite   Breccia  ...   No data  No data       No data
# 4    No data  Metavolcanic  Porphyry  ...   No data  No data       No data
#
#   LithColor4 LithAbund5 LithSpec5 LithMod5 LithColorMod5 LithColor5  \
# 0    No data    No data   No data  No data       No data    No data
# 1    No data    No data   No data  No data       No data    No data
# 2    No data    No data   No data  No data       No data    No data
# 3    No data    No data   No data  No data       No data    No data
# 4    No data    No data   No data  No data       No data    No data
#
#   Lithology_Category
# 0            No data
# 1            No data
# 2            No data
# 3            No data
# 4            No data
#
# [5 rows x 33 columns]

# %%
def plot_lithology_types(lit_types):

  for lit_type in lit_types:


    # Sample Data
    geol_from = alt_data["GeolFrom"]
    geol_to = alt_data["GeolTo"]
    lith_spec1 = lit_data[lit_type]

    # Calculate the widths of each bar segment (GeolTo - GeolFrom)
    bar_lengths = [end - start for start, end in zip(geol_from, geol_to)]

    # Choose a color scale
    color_scale = px.colors.qualitative.Set2  # A qualitative color scale with 9 distinct colors

    # Map each lithology type to a color from the chosen color scale
    color_mapping = {lith: color_scale[i % len(color_scale)] for i, lith in enumerate(set(lith_spec1))}

    # Create a figure for the plot
    fig = go.Figure()

    # Track lithology types that have already appeared in the legend
    legend_seen = {}

    # Add each lithology type as a separate segment in the same bar
    start_point = 0
    for lith, length in zip(lith_spec1, bar_lengths):
        show_legend = lith not in legend_seen  # Show legend only for the first occurrence of each lithology
        legend_seen[lith] = True  # Mark this lithology as seen

        fig.add_trace(go.Bar(
            y=[0],  # All bars are at the same y=0 level to stack on the same line
            x=[length],  # Length of the bar segment
            orientation='h',  # Horizontal bars
            name=lith,  # Name for legend
            offsetgroup=0,  # Stack the bars
            base=start_point,  # Set the base of the bar where the last ended
            marker_color=color_mapping[lith],  # Assign color based on lithology type
            marker_line_width=0,  # Remove the border line
            legendgroup=lith,  # Group all traces with the same lithology into one legend entry
            showlegend=show_legend  # Show legend only for the first trace of each lithology type
        ))
        start_point += length  # Update the start_point for the next segment

    # Update layout for stacked bar and styling
    fig.update_layout(
        xaxis_title="Depth (m)",
        yaxis=dict(showticklabels=False),  # Hide y-axis ticks and labels
        barmode='stack',  # Stack bars on top of each other
        showlegend=True,
        height=300,  # Set plot height
        legend_title="Lithology Type",

    )

    # Show the plot
    fig.show()

# %%
lit_types = ['LithSpec1', 'LithSpec2', 'LithSpec3']
plot_lithology_types(lit_types)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="745e1db1-1d98-491e-84e1-78294040acb5" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("745e1db1-1d98-491e-84e1-78294040acb5")) {                    Plotly.newPlot(                        "745e1db1-1d98-491e-84e1-78294040acb5",                        [{"base":0,"legendgroup":"Andesite","marker":{"color":"rgb(141,160,203)","line":{"width":0}},"name":"Andesite","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"Andesite","marker":{"color":"rgb(141,160,203)","line":{"width":0}},"name":"Andesite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"Andesite","marker":{"color":"rgb(141,160,203)","line":{"width":0}},"name":"Andesite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"Andesite","marker":{"color":"rgb(141,160,203)","line":{"width":0}},"name":"Andesite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"Metavolcanic","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"Metavolcanic","offsetgroup":"0","orientation":"h","showlegend":true,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"Metavolcanic","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"Metavolcanic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"QuartzVein","marker":{"color":"rgb(229,196,148)","line":{"width":0}},"name":"QuartzVein","offsetgroup":"0","orientation":"h","showlegend":true,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"Andesite","marker":{"color":"rgb(141,160,203)","line":{"width":0}},"name":"Andesite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"Metavolcanic","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"Metavolcanic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"Metandesite","marker":{"color":"rgb(252,141,98)","line":{"width":0}},"name":"Metandesite","offsetgroup":"0","orientation":"h","showlegend":true,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"QuartzVein","marker":{"color":"rgb(229,196,148)","line":{"width":0}},"name":"QuartzVein","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"Metandesite","marker":{"color":"rgb(252,141,98)","line":{"width":0}},"name":"Metandesite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"Metandesite","marker":{"color":"rgb(252,141,98)","line":{"width":0}},"name":"Metandesite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"Metavolcanic","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"Metavolcanic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"Metavolcanic","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"Metavolcanic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"Metavolcanic","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"Metavolcanic","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"bas ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7a72738e-2b00-4cc9-bf24-84a1bf8aac91" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a72738e-2b00-4cc9-bf24-84a1bf8aac91")) {                    Plotly.newPlot(                        "7a72738e-2b00-4cc9-bf24-84a1bf8aac91",                        [{"base":0,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"base":79.25,"legendgroup":"Metavolcanic","marker":{"color":"rgb(141,160,203)","line":{"width":0}},"name ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="be782f29-63f3-4947-a5ff-685e53cd4fa2" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("be782f29-63f3-4947-a5ff-685e53cd4fa2")) {                    Plotly.newPlot(                        "be782f29-63f3-4947-a5ff-685e53cd4fa2",                        [{"base":0,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No data","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"base":79.25,"legendgroup":"No data","marker":{"color":"rgb(102,194,165)","line":{"width":0}},"name":"No ...

# %% [markdown]
# recovery

# %%
rec_file_path = "/content/Evelyn_Recovery_RQD_20241120.csv"
rec_data = pd.read_csv(rec_file_path)
rec_data.head()
# Out:
#       Collar  GeolFrom  GeolTo  Chk  RQDraw  RecoveryRaw  Recovery   RQD  \
# 0  EVE-20-01       0.0     2.2    0    0.00         0.40     18.18   0.0
# 1  EVE-20-01       2.2     5.2    0    0.36         2.48     82.67  12.0
# 2  EVE-20-01       5.2     8.2    0    1.00         2.45     81.67  33.0
# 3  EVE-20-01       8.2     9.2    0    0.68         0.98     98.00  68.0
# 4  EVE-20-01       9.2     9.8    0    0.00         0.30     50.00   0.0
#
#    Longest_Piece       Rock_Strength Hardness  Comments
# 0              0  R3_Moderately_Weak  No data       NaN
# 1              0  R3_Moderately_Weak  No data       NaN
# 2              0  R3_Moderately_Weak  No data       NaN
# 3              0  R3_Moderately_Weak  No data       NaN
# 4              0  R3_Moderately_Weak  No data       NaN

# %%
rec_data['Recovery'].max()
# Out:
# 100.0

# %%
recovery_data = rec_data["Recovery"]
total_depth = list(set(rec_data['GeolFrom']).union(set(rec_data['GeolTo'])))


fig = go.Figure()

fig.add_trace(go.Bar(
      y=recovery_data,
      x=total_depth,
      #orientation='v',
      name='Recovery',
      marker=dict(color='red')


))


fig.update_layout(
    xaxis_title="Depth (m)",
    yaxis_title="Recovery (kg)",
    yaxis=dict(showticklabels=True),
    showlegend=True,
    height=400,  # Set plot height
    legend_title="Recovery (kg)"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="43254731-d8c4-4508-87ff-3b21fd33857d" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43254731-d8c4-4508-87ff-3b21fd33857d")) {                    Plotly.newPlot(                        "43254731-d8c4-4508-87ff-3b21fd33857d",                        [{"marker":{"color":"red"},"name":"Recovery","x":[0.0,2.2,5.2,8.2,9.2,9.8,10.15,10.55,11.4,12.25,13.2,13.55,14.15,15.55,17.1,18.6,20.2,22.1,24.2,26.2,29.2,31.8,32.2,35.2,38.2,41.2,42.5,44.2,46.1,47.2,49.6,52.05,53.2,55.85,59.05,62.2,65.2,67.4,69.0,71.2,74.2,77.2,80.2,83.2,86.2,89.2,92.2,95.2,98.2,101.2,104.2,107.2,110.2,113.2,116.2,119.2,122.2,123.9,125.2,128.2,131.2,134.2,137.2,140.2,143.2,146.2,149.2,152.2,155.2],"y":[18.18,82.67,81.67,98.0,50.0,0.0,62.5,94.12,70.59,73.68,85.71,91.67,71.43,90.32,100.0,93.75,84.21,95.24,100.0,91.67,61.54,75.0,93.33,93.33,95.0,80.77,70.59,84.21,63.64,70.83,93.88,91.3,88.68,96.88,87.3,73.33,93.18,81.25,95.46,86.67,75.0,80.0,86.67,93.33,93.33,95.0,95.0,96.67,90.0,93.33,91.67,90.0,98.33,93.33,86.67,90.0,88.24,88.46,91.67,96.67,96.67,91.67,95.0,91.67,93.33,98.33,96.67,96.67],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}], ...

# %% [markdown]
# RQD

# %%
recovery_data = rec_data["RQD"]
total_depth = list(set(rec_data['GeolFrom']).union(set(rec_data['GeolTo'])))


fig = go.Figure()

fig.add_trace(go.Bar(
      y=recovery_data,
      x=total_depth,
      #orientation='v',
      name='RQD',
      marker=dict(color='blue')


))


fig.update_layout(
    xaxis_title="Depth (m)",
    yaxis_title="RQD",
    yaxis=dict(showticklabels=True),
    showlegend=True,
    height=400,  # Set plot height
    legend_title="RQD"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0839a0e9-91f0-4595-a70e-08ec587b97db" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0839a0e9-91f0-4595-a70e-08ec587b97db")) {                    Plotly.newPlot(                        "0839a0e9-91f0-4595-a70e-08ec587b97db",                        [{"marker":{"color":"blue"},"name":"RQD","x":[0.0,2.2,5.2,8.2,9.2,9.8,10.15,10.55,11.4,12.25,13.2,13.55,14.15,15.55,17.1,18.6,20.2,22.1,24.2,26.2,29.2,31.8,32.2,35.2,38.2,41.2,42.5,44.2,46.1,47.2,49.6,52.05,53.2,55.85,59.05,62.2,65.2,67.4,69.0,71.2,74.2,77.2,80.2,83.2,86.2,89.2,92.2,95.2,98.2,101.2,104.2,107.2,110.2,113.2,116.2,119.2,122.2,123.9,125.2,128.2,131.2,134.2,137.2,140.2,143.2,146.2,149.2,152.2,155.2],"y":[0.0,12.0,33.0,68.0,0.0,0.0,0.0,12.0,0.0,11.0,29.0,67.0,20.0,13.0,50.0,36.0,37.0,50.0,45.0,47.0,15.0,25.0,63.0,67.0,47.0,0.0,6.0,36.0,24.0,13.0,33.0,48.0,18.0,42.0,26.0,28.0,33.0,11.0,64.0,36.0,10.0,27.0,15.0,30.0,50.0,78.0,71.0,67.0,39.0,56.0,29.0,39.0,23.0,57.0,30.0,16.0,81.0,98.0,35.0,37.0,50.0,48.0,47.0,43.0,43.0,45.0,38.0,53.0],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinew ...

# %% [markdown]
# Specific Gravity

# %%
gravity_file_path = "/content/Evelyn_Specific_Gravity_20241120.csv"
gravity_data = pd.read_csv(gravity_file_path)
gravity_data.head()
# Out:
#       Collar  Depth  Chk  Length  WeightDryAir  WeightWater  \
# 0  EVE-20-01   2.65    0     8.0         327.7        -9999
# 1  EVE-20-01   3.65    0     8.0         210.5        -9999
# 2  EVE-20-01   5.55    0    11.0         363.7        -9999
# 3  EVE-20-01   7.15    0    12.0         418.6        -9999
# 4  EVE-20-01   7.65    0    12.0         389.5        -9999
#
#    WeightWaterSealed  FinalWeightNoSealed  Chk1  SpecificGravity_1  Vol_1  \
# 0              118.2                -9999     0              2.772  -9999
# 1               77.0                -9999     0              2.734  -9999
# 2              135.6                -9999     0              2.682  -9999
# 3              132.2                -9999     0              3.166  -9999
# 4              139.2                -9999     0              2.798  -9999
#
#    Vol_2  DifVol  SpecificGravity_2  SpecificGravityComment
# 0  -9999   -9999              -9999                     NaN
# 1  -9999   -9999              -9999                     NaN
# 2  -9999   -9999              -9999                     NaN
# 3  -9999   -9999              -9999                     NaN
# 4  -9999   -9999              -9999                     NaN

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=gravity_data['Depth'], y=gravity_data['SpecificGravity_1'], mode='lines', line=dict(color='blue'), fill='tozeroy', fillcolor='rgba(0, 0, 255, 0.3)', name='Specific Gravity'))

fig.update_layout(
    xaxis_title="Depth (m)",
    yaxis_title="Specific Gravity",
    showlegend=True,
    height=400,  # Set plot height
    legend_title="Specific Gravity"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b719961b-a921-4827-a8f7-858b9bc487a7" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b719961b-a921-4827-a8f7-858b9bc487a7")) {                    Plotly.newPlot(                        "b719961b-a921-4827-a8f7-858b9bc487a7",                        [{"fill":"tozeroy","fillcolor":"rgba(0, 0, 255, 0.3)","line":{"color":"blue"},"mode":"lines","name":"Specific Gravity","x":[2.65,3.65,5.55,7.15,7.65,9.45,10.55,12.8,13.6,15.35,16.75,18.2,19.25,20.65,22.35,23.85,25.25,27.95,28.55,29.2,31.05,31.9,32.65,33.5,35.3,37.75,40.4,41.65,43.85,45.8,46.85,48.6,50.7,52.95,54.2,56.35,59.85,64.8,67.35,68.2,71.0,73.8,76.4,79.7,81.5,86.7,93.1,98.3,106.2,116.3,121.6,123.7,127.7,132.5,139.1,143.95,148.5,154.8],"y":[2.772,2.734,2.682,3.166,2.798,2.727,2.947,2.797,2.807,2.421,2.695,2.443,3.038,2.697,3.439,2.859,2.726,2.716,2.591,3.165,2.905,2.661,2.688,2.755,2.589,2.682,2.662,2.631,3.013,2.62,2.691,2.576,2.616,2.694,2.823,2.668,2.685,2.599,2.548,2.705,2.581,2.474,2.422,2.66,2.557,2.67,2.529,2.657,2.688,2.755,2.993,2.855,2.689,2.801,2.762,2.717,2.788,2.5],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"ty ...

# %% [markdown]
# Au PPM

# %%
au_ppm_file_path = "/content/Evelyn_Samples_20241120.csv"
au_ppm_data = pd.read_csv(au_ppm_file_path)
au_ppm_data.head()
# Out:
#       Collar  Sample ID  Geol_From  Geol_To  Thickness  Chk  Comments  Lab  \
# 0  EVE-20-01     779202        0.0      2.2        2.2  0.0       NaN  ALS
# 1  EVE-20-01     779203        2.2      3.7        1.5  0.0       NaN  ALS
# 2  EVE-20-01     779204        3.7      5.2        1.5  0.0       NaN  ALS
# 3  EVE-20-01     779205        5.2      6.5        1.3  0.0       NaN  ALS
# 4  EVE-20-01     779206        6.5      7.8        1.3  0.0       NaN  ALS
#
#          Dispatch_ID         Lab_Certificate  ... Te_ppm_ME-MS61  \
# 0  EVE2001_Batch_001  HE20068262 - Finalized  ...        No data
# 1  EVE2001_Batch_001  HE20068262 - Finalized  ...        No data
# 2  EVE2001_Batch_001  HE20068262 - Finalized  ...        No data
# 3  EVE2001_Batch_001  HE20068262 - Finalized  ...        No data
# 4  EVE2001_Batch_001  HE20068262 - Finalized  ...        No data
#
#   Th_ppm_ME-MS61  Ti_%_ME-MS61 Tl_ppm_ME-MS61 U_ppm_ME-MS61  V_ppm_ME-MS61  \
# 0        No data       No data        No data       No data        No data
# 1        No data       No data        No data       No data        No data
# 2        No data       No data        No data       No data        No data
# 3        No data       No data        No data       No data        No data
# 4        No data       No data        No data       No data        No data
#
#   W_ppm_ME-MS61 Y_ppm_ME-MS61 Zn_ppm_ME-MS61  Zr_ppm_ME-MS61
# 0       No data       No data        No data         No data
# 1       No data       No data        No data         No data
# 2       No data       No data        No data         No data
# 3       No data       No data        No data         No data
# 4       No data       No data        No data         No data
#
# [5 rows x 66 columns]

# %%
def plot_element_ppm(elements):
  for element in elements:

    total_depth = list(set(au_ppm_data['Geol_From']).union(set(au_ppm_data['Geol_To'])))

    fig = go.Figure()

    fig.add_trace(go.Bar(x=total_depth, y=au_ppm_data[element], name=f"{element[:2]} PPM", marker=dict(color='blue')))

    fig.update_layout(
        xaxis_title="Depth (m)",
        yaxis_title=f"{element[:2]} PPM",
        showlegend=True,
        height=400,  # Set plot height
        legend_title=f"{element[:2]} PPM"
    )

    fig.show()

# %%
elements = ["Ag_ppm_Ag-AA61", "Au_ppm_Au-AA24"]
plot_element_ppm(elements)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dd208509-551d-4d58-9a57-824a3d8282dc" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd208509-551d-4d58-9a57-824a3d8282dc")) {                    Plotly.newPlot(                        "dd208509-551d-4d58-9a57-824a3d8282dc",                        [{"marker":{"color":"blue"},"name":"Ag PPM","x":[0.0,2.2,3.7,5.2,6.5,7.8,9.1,10.15,10.8,11.4,13.0,14.5,9.8,16.0,17.5,19.0,20.5,22.0,23.5,25.1,26.7,28.3,29.05,30.0,31.5,32.55,33.35,35.0,36.5,38.0,39.5,40.5,41.2,42.7,44.2,45.7,47.2,48.7,50.2,51.7,53.2,54.7,56.2,57.7,59.2,60.7,62.2,63.7,65.2,66.7,68.2,69.7,71.2,72.7,74.2,75.7,77.2,78.7,80.2,81.7,83.2,84.7,86.2,87.7,89.2,90.7,92.2,93.7,95.2,96.7,98.2,99.7,101.2,102.7,104.2,105.7,107.2,108.7,110.2,111.7,113.2,114.7,116.2,117.7,119.2,120.7,122.2,123.7,125.2,126.7,128.2,129.7,131.2,132.7,134.2,135.7,137.2,138.7,140.2,141.7,143.2,144.7,146.2,147.7,149.2,150.7,152.2,153.7,155.2],"y":[0.25,0.25,0.6,0.25,0.25,0.25,0.25,0.8,0.25,0.25,0.25,0.25,0.25,0.25,0.25,0.8,0.25,0.25,0.25,0.6,3.2,1.3,1.2,1.0,1.4,0.5,0.7,0.7,1.5,1.4,1.5,1.4,1.5,1.3,2.0,2.6,3.4,2.4,2.0,1.6,1.8,1.2,0.8,0.9,1.7,1.8,1.1,1.0,1.4,0.8,0.8,1.2,0.7,1.5,1.0,0.8,1.1,1.3,2.3,4.6,1.8,1.2,0.6,1.3,1.2,0.25,1.2,0.25,1.4,0.6,0.6,1.2,23.1,0.5,0.9,1.3,0.5,0.25,0.7,2.1,4.6,2.2,2.5,5.4,6.4,0.25,0.25,3.0,2.7,0.25,0.25,0.8,0.25,0.25,0.25,0.25,0.25,2.2,0.25,0.25,0.25,0.25,0.9,0.6,0.5,0.5,0.25],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d857 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="40d84c2d-b166-41d8-a7f0-7e681ac49235" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40d84c2d-b166-41d8-a7f0-7e681ac49235")) {                    Plotly.newPlot(                        "40d84c2d-b166-41d8-a7f0-7e681ac49235",                        [{"marker":{"color":"blue"},"name":"Au PPM","x":[0.0,2.2,3.7,5.2,6.5,7.8,9.1,10.15,10.8,11.4,13.0,14.5,9.8,16.0,17.5,19.0,20.5,22.0,23.5,25.1,26.7,28.3,29.05,30.0,31.5,32.55,33.35,35.0,36.5,38.0,39.5,40.5,41.2,42.7,44.2,45.7,47.2,48.7,50.2,51.7,53.2,54.7,56.2,57.7,59.2,60.7,62.2,63.7,65.2,66.7,68.2,69.7,71.2,72.7,74.2,75.7,77.2,78.7,80.2,81.7,83.2,84.7,86.2,87.7,89.2,90.7,92.2,93.7,95.2,96.7,98.2,99.7,101.2,102.7,104.2,105.7,107.2,108.7,110.2,111.7,113.2,114.7,116.2,117.7,119.2,120.7,122.2,123.7,125.2,126.7,128.2,129.7,131.2,132.7,134.2,135.7,137.2,138.7,140.2,141.7,143.2,144.7,146.2,147.7,149.2,150.7,152.2,153.7,155.2],"y":[0.005,0.0025,0.0025,0.0025,0.01,0.0025,0.005,0.0025,0.0025,0.025,0.0025,0.0025,0.0025,0.006,0.0025,0.056,0.01,0.009,0.0025,0.02,0.292,0.2,0.862,0.021,0.189,0.008,0.011,0.045,0.008,0.017,0.017,0.07,0.038,0.028,0.109,0.274,0.167,0.078,0.082,0.075,0.159,0.034,0.026,0.024,0.21,0.059,0.026,0.046,0.131,0.03,0.031,0.01,0.056,0.082,0.013,0.027,0.073,0.11,0.044,0.122,0.08,0.062,0.061,0.047,0.018,0.006,0.042,0.024,0.084,0.055,0.066,0.083,0.113,0.023,0.062,0.057,0.043,0.013,0.067,0.053,0.192,0.128,0.108,0.073,0.105,0.033,0.02,0.133,0.141,0.0025,0.01,0.19,0.125,0.024,0.0025,0.0025,0.042,0.41,0.023,0.02,0.094,0.0025,0.056,0.092,0.133,0.061,0.02],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"c ...

# %% [markdown]
# mineralization

# %%
min_filepath = "/content/Evelyn_Mineralisation_20241120.csv"
min_data = pd.read_csv(min_filepath)
min_data.head()
# Out:
#       Collar  GeolFrom  GeolTo  Chk    Mineral_Comments  No_Qtz_Veins  \
# 0  EVE-20-01       0.0     9.1    0  Qtz clear veinlets         -9999
# 1  EVE-20-01       9.1    17.7    0                 NaN         -9999
# 2  EVE-20-01      17.7    20.7    0                 NaN         -9999
# 3  EVE-20-01      20.7    23.0    0                 NaN         -9999
# 4  EVE-20-01      23.0    26.4    0                 NaN         -9999
#
#   Mineral1 Mineral_Style1  Mineral1_Percent  Mineral2  ... Mineral9_Percent  \
# 0   Quartz        No data               0.5  Hematite  ...                0
# 1   Quartz        No data               0.5  Goethite  ...                0
# 2   Quartz        No data               0.5  Hematite  ...                0
# 3   Quartz        No data               0.9  Hematite  ...                0
# 4   Quartz        No data               0.1  Goethite  ...                0
#
#    Mineral10 Mineral_Style10 Mineral10_Percent  Mineral11 Mineral_Style11  \
# 0    No data         No data                 0    No data         No data
# 1    No data         No data                 0    No data         No data
# 2    No data         No data                 0    No data         No data
# 3    No data         No data                 0    No data         No data
# 4    No data         No data                 0    No data         No data
#
#   Mineral11_Percent  Mineral12 Mineral_Style12 Mineral12_Percent
# 0                 0    No data         No data                 0
# 1                 0    No data         No data                 0
# 2                 0    No data         No data                 0
# 3                 0    No data         No data                 0
# 4                 0    No data         No data                 0
#
# [5 rows x 42 columns]

# %%
def plot_mineral_type(min_types):

  for min_type in min_types:


    # Sample Data
    geol_from = min_data["GeolFrom"]
    geol_to = min_data["GeolTo"]
    min_spec = min_data[min_type]

    # Calculate the widths of each bar segment (GeolTo - GeolFrom)
    bar_lengths = [end - start for start, end in zip(geol_from, geol_to)]

    # Choose a color scale
    color_scale = px.colors.qualitative.Set1  # A qualitative color scale with 9 distinct colors

    # Map each lithology type to a color from the chosen color scale
    color_mapping = {alt: color_scale[i % len(color_scale)] for i, alt in enumerate(set(min_spec))}

    # Create a figure for the plot
    fig = go.Figure()

    # Track lithology types that have already appeared in the legend
    legend_seen = {}

    # Add each lithology type as a separate segment in the same bar
    start_point = 0
    for alt, length in zip(min_spec, bar_lengths):
        show_legend = alt not in legend_seen  # Show legend only for the first occurrence of each lithology
        legend_seen[alt] = True  # Mark this lithology as seen

        fig.add_trace(go.Bar(
            y=[0],  # All bars are at the same y=0 level to stack on the same line
            x=[length],  # Length of the bar segment
            orientation='h',  # Horizontal bars
            name=alt,  # Name for legend
            offsetgroup=0,  # Stack the bars
            base=start_point,  # Set the base of the bar where the last ended
            marker_color=color_mapping[alt],  # Assign color based on lithology type
            marker_line_width=0,  # Remove the border line
            legendgroup=alt,  # Group all traces with the same lithology into one legend entry
            showlegend=show_legend  # Show legend only for the first trace of each lithology type
        ))
        start_point += length  # Update the start_point for the next segment

    # Update layout for stacked bar and styling
    fig.update_layout(
        xaxis_title="Depth (m)",
        yaxis=dict(showticklabels=False),  # Hide y-axis ticks and labels
        barmode='stack',  # Stack bars on top of each other
        showlegend=True,
        height=300,  # Set plot height
        legend_title="Alteration Type"
    )

    # Show the plot
    fig.show()

# %%
min_types = ["Mineral1", "Mineral2", "Mineral3"]
plot_mineral_type(min_types)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="48d35dac-b9c3-49f5-817c-05ffe16ed0ec" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48d35dac-b9c3-49f5-817c-05ffe16ed0ec")) {                    Plotly.newPlot(                        "48d35dac-b9c3-49f5-817c-05ffe16ed0ec",                        [{"base":0,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"base":79.25,"legendgroup":"Quartz","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Quartz","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2efd6cd1-cff0-4178-b13c-811b0638ca67" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2efd6cd1-cff0-4178-b13c-811b0638ca67")) {                    Plotly.newPlot(                        "2efd6cd1-cff0-4178-b13c-811b0638ca67",                        [{"base":0,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"Goethite","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":true,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"Goethite","marker":{"color":"rgb(152,78,163)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"base":79.25,"legendgroup":"Pyrite","marker":{"color":"rgb(228,26,28)","line":{"width":0} ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="81348041-8c83-4026-9620-6d4f724af5be" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81348041-8c83-4026-9620-6d4f724af5be")) {                    Plotly.newPlot(                        "81348041-8c83-4026-9620-6d4f724af5be",                        [{"base":0,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":true,"x":[9.1],"y":[0],"type":"bar"},{"base":9.1,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":true,"x":[8.6],"y":[0],"type":"bar"},{"base":17.7,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.0],"y":[0],"type":"bar"},{"base":20.7,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.3000000000000007],"y":[0],"type":"bar"},{"base":23.0,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"Hematite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.3999999999999986],"y":[0],"type":"bar"},{"base":26.4,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[1.9000000000000021],"y":[0],"type":"bar"},{"base":28.3,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.75],"y":[0],"type":"bar"},{"base":29.05,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[3.7499999999999964],"y":[0],"type":"bar"},{"base":32.8,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[0.5500000000000043],"y":[0],"type":"bar"},{"base":33.35,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[6.549999999999997],"y":[0],"type":"bar"},{"base":39.9,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6000000000000014],"y":[0],"type":"bar"},{"base":42.5,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.549999999999997],"y":[0],"type":"bar"},{"base":48.05,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[2.6500000000000057],"y":[0],"type":"bar"},{"base":50.7,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[14.849999999999994],"y":[0],"type":"bar"},{"base":65.55,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[5.700000000000003],"y":[0],"type":"bar"},{"base":71.25,"legendgroup":"Goethite","marker":{"color":"rgb(228,26,28)","line":{"width":0}},"name":"Goethite","offsetgroup":"0","orientation":"h","showlegend":false,"x":[8.0],"y":[0],"type":"bar"},{"base":79.25,"legendgroup":"Hematite","marker":{"color":"rgb(55,126,184)","line":{"width":0}},"name":"H ...
